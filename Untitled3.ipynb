# %% [markdown]
# <a href="https://colab.research.google.com/github/MoumitaRoy13/RNASequence_Analysis_Project/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/FelixKrueger/TrimGalore/archive/refs/tags/0.6.10.zip
# !unzip 0.6.10.zip
# !chmod +x TrimGalore-0.6.10/trim_galore
# Out:
# --2024-10-27 05:57:28--  https://github.com/FelixKrueger/TrimGalore/archive/refs/tags/0.6.10.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/FelixKrueger/TrimGalore/zip/refs/tags/0.6.10 [following]
# --2024-10-27 05:57:29--  https://codeload.github.com/FelixKrueger/TrimGalore/zip/refs/tags/0.6.10
# Resolving codeload.github.com (codeload.github.com)... 20.27.177.114
# Connecting to codeload.github.com (codeload.github.com)|20.27.177.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘0.6.10.zip’
#
# 0.6.10.zip              [      <=>           ]  25.59M  16.9MB/s    in 1.5s
#
# 2024-10-27 05:57:31 (16.9 MB/s) - ‘0.6.10.zip’ saved [26835264]
#
# Archive:  0.6.10.zip
# 4edff97d22f3837d42a29e4afbfaeb6e07ffb11b
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17159276_1.fastq /content/drive/MyDrive/SRR17159276_2.fastq -o /content/drive/MyDrive/trimmed_output/
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 4.9
# single-core operation.
# igzip command line interface 2.30.0
# igzip detected. Using igzip for decompressing
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/drive/MyDrive/trimmed_output/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /content/drive/MyDrive/SRR17159276_1.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	291075	AGATCGGAAGAGC	1000000	29.11
# smallRNA	8	TGGAATTCTCGG	1000000	0.00
# Nextera	0	CTGTCTCTTATA	1000000	0.00
# ...

# %%
# !pip install cutadapt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.7/287.7 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.9/258.9 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 6.9 MB/s eta 0:00:00
# ...

# %%
# !apt-get install -y isal
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libisal2
# The following NEW packages will be installed:
#   isal libisal2
# 0 upgraded, 2 newly installed, 0 to remove and 49 not upgraded.
# Need to get 121 kB of archives.
# After this operation, 403 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libisal2 amd64 2.30.0-4 [110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 isal amd64 2.30.0-4 [10.7 kB]
# Fetched 121 kB in 1s (135 kB/s)
# Selecting previously unselected package libisal2.
# (Reading database ... 123622 files and directories currently installed.)
# Preparing to unpack .../libisal2_2.30.0-4_amd64.deb ...
# Unpacking libisal2 (2.30.0-4) ...
# Selecting previously unselected package isal.
# Preparing to unpack .../isal_2.30.0-4_amd64.deb ...
# Unpacking isal (2.30.0-4) ...
# ...

# %%
# !mv TrimGalore-0.6.10/trim_galore /usr/local/bin/

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17159276_1_val_1.fq \
       -2 /content/drive/MyDrive/trimmed_output/SRR17159276_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17159276_aligned.sam
# Out:
# 15883761 reads; of these:
#   15883761 (100.00%) were paired; of these:
#     384587 (2.42%) aligned concordantly 0 times
#     12371394 (77.89%) aligned concordantly exactly 1 time
#     3127780 (19.69%) aligned concordantly >1 times
#     ----
#     384587 pairs aligned concordantly 0 times; of these:
#       17653 (4.59%) aligned discordantly 1 time
#     ----
#     366934 pairs aligned 0 times concordantly or discordantly; of these:
#       733868 mates make up the pairs; of these:
#         416386 (56.74%) aligned 0 times
#         247970 (33.79%) aligned exactly 1 time
#         69512 (9.47%) aligned >1 times
# 98.69% overall alignment rate

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17159276_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17159276_sorted.bam
# Out:
# [bam_sort_core] merging from 17 files and 1 in-memory blocks...

# %%
# !samtools index /content/drive/MyDrive/SRR17159276_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17159276_sorted.bam
# Out:
# 39023740 + 0 in total (QC-passed reads + QC-failed reads)
# 31767522 + 0 primary
# 7256218 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 38607354 + 0 mapped (98.93% : N/A)
# 31351136 + 0 primary mapped (98.69% : N/A)
# 31767522 + 0 paired in sequencing
# 15883761 + 0 read1
# 15883761 + 0 read2
# 30998348 + 0 properly paired (97.58% : N/A)
# 31098996 + 0 with itself and mate mapped
# 252140 + 0 singletons (0.79% : N/A)
# 71492 + 0 with mate mapped to a different chr
# 46259 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !apt-get install -y hisat2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   bcftools libhts3 libhtscodecs2 python3-hisat2 samtools
# Suggested packages:
#   python3-numpy python3-matplotlib texlive-latex-recommended cwltool
# The following NEW packages will be installed:
#   bcftools hisat2 libhts3 libhtscodecs2 python3-hisat2 samtools
# 0 upgraded, 6 newly installed, 0 to remove and 49 not upgraded.
# Need to get 5,505 kB of archives.
# After this operation, 17.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhtscodecs2 amd64 1.1.1-3 [53.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhts3 amd64 1.13+ds-2build1 [390 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 bcftools amd64 1.13-1 [697 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 hisat2 amd64 2.2.1-3 [3,832 kB]
# ...

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17159276_counts.txt -T 4 /content/drive/MyDrive/SRR17159276_sorted.bam
# Out:
# /bin/bash: line 1: featureCounts: command not found

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17159276_counts.txt -T 4 -p /content/drive/MyDrive/SRR17159276_sorted.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                                                                            ||
# ||                           SRR17159276_sorted.bam                           ||
# ||                                                                            ||
# ...

# %%
# !apt-get install -y subread
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   subread
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 565 kB of archives.
# After this operation, 1,928 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 subread amd64 2.0.3+dfsg-1 [565 kB]
# Fetched 565 kB in 2s (297 kB/s)
# Selecting previously unselected package subread.
# (Reading database ... 123622 files and directories currently installed.)
# Preparing to unpack .../subread_2.0.3+dfsg-1_amd64.deb ...
# Unpacking subread (2.0.3+dfsg-1) ...
# Setting up subread (2.0.3+dfsg-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17158946_1.fastq /content/drive/MyDrive/SRR17158946_2.fastq -o /content/drive/MyDrive/trimmed_output/
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 4.9
# single-core operation.
# Proceeding with 'gzip' for decompression
# To decrease CPU usage of decompression, please install 'igzip' and run again
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/drive/MyDrive/trimmed_output/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /content/drive/MyDrive/SRR17158946_1.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	13583	AGATCGGAAGAGC	1000000	1.36
# Nextera	1	CTGTCTCTTATA	1000000	0.00
# smallRNA	0	TGGAATTCTCGG	1000000	0.00
# ...

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17158978_1.fastq /content/drive/MyDrive/SRR17158978_2.fastq -o /content/drive/MyDrive/trimmed_output/
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 4.9
# single-core operation.
# Proceeding with 'gzip' for decompression
# To decrease CPU usage of decompression, please install 'igzip' and run again
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/drive/MyDrive/trimmed_output/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /content/drive/MyDrive/SRR17158978_1.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	19674	AGATCGGAAGAGC	1000000	1.97
# Nextera	1	CTGTCTCTTATA	1000000	0.00
# smallRNA	0	TGGAATTCTCGG	1000000	0.00
# ...

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17158944_1.fastq /content/drive/MyDrive/SRR17158944_2.fastq -o /content/drive/MyDrive/trimmed_output/
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 4.9
# single-core operation.
# Proceeding with 'gzip' for decompression
# To decrease CPU usage of decompression, please install 'igzip' and run again
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/drive/MyDrive/trimmed_output/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /content/drive/MyDrive/SRR17158944_1.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	16616	AGATCGGAAGAGC	1000000	1.66
# Nextera	0	CTGTCTCTTATA	1000000	0.00
# smallRNA	0	TGGAATTCTCGG	1000000	0.00
# ...

# %%
# !apt-get update
# !apt-get install -y hisat2
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,071 kB]
# Ign:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17158944_1_val_1.fq\
       -2 /content/drive/MyDrive/trimmed_output/SRR17158944_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17158944_aligned.sam
# Out:
# 39475521 reads; of these:
#   39475521 (100.00%) were paired; of these:
#     1827933 (4.63%) aligned concordantly 0 times
#     30964363 (78.44%) aligned concordantly exactly 1 time
#     6683225 (16.93%) aligned concordantly >1 times
#     ----
#     1827933 pairs aligned concordantly 0 times; of these:
#       174626 (9.55%) aligned discordantly 1 time
#     ----
#     1653307 pairs aligned 0 times concordantly or discordantly; of these:
#       3306614 mates make up the pairs; of these:
#         1695730 (51.28%) aligned 0 times
#         1197803 (36.22%) aligned exactly 1 time
#         413081 (12.49%) aligned >1 times
# 97.85% overall alignment rate

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17158944_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17158944_sorted.bam
# Out:
# [bam_sort_core] merging from 45 files and 1 in-memory blocks...

# %%
# !samtools index /content/drive/MyDrive/SRR17158944_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17158944_sorted.bam
# Out:
# 115919732 + 0 in total (QC-passed reads + QC-failed reads)
# 78951042 + 0 primary
# 36968690 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 114224002 + 0 mapped (98.54% : N/A)
# 77255312 + 0 primary mapped (97.85% : N/A)
# 78951042 + 0 paired in sequencing
# 39475521 + 0 read1
# 39475521 + 0 read2
# 75295176 + 0 properly paired (95.37% : N/A)
# 76362976 + 0 with itself and mate mapped
# 892336 + 0 singletons (1.13% : N/A)
# 991008 + 0 with mate mapped to a different chr
# 740675 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !apt-get install -y subread
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# subread is already the newest version (2.0.3+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17158944_counts.txt -T 4 -p /content/drive/MyDrive/SRR17158944_sorted.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                                                                            ||
# ||                           SRR17158944_sorted.bam                           ||
# ||                                                                            ||
# ...
