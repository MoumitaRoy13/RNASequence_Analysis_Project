# %% [markdown]
# <a href="https://colab.research.google.com/github/MoumitaRoy13/RNASequence_Analysis_Project/blob/main/RNASEQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install fastqc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jre default-jre-headless fonts-dejavu-core fonts-dejavu-extra libapache-pom-java
#   libargs4j-java libatk-wrapper-java libatk-wrapper-java-jni libcommons-compress-java
#   libcommons-io-java libcommons-jexl2-java libcommons-lang3-java libcommons-logging-java
#   libcommons-math3-java libcommons-parent-java libfindbin-libs-perl libfontenc1 libhtsjdk-java
#   libjbzip2-java libjson-simple-java libngs-java libngs-sdk-dev libngs-sdk2 libsis-base-java
#   libsis-base-jni libsis-jhdf5-java libsis-jhdf5-jni libsnappy-java libsnappy-jni libxkbfile1
#   libxtst6 libxxf86dga1 openjdk-11-jre x11-utils
# Suggested packages:
#   libxz-java libcommons-io-java-doc libcommons-lang3-java-doc libavalon-framework-java
#   libcommons-logging-java-doc libexcalibur-logkit-java liblog4j1.2-java picard-tools
# ...

# %%
# !fastqc /content/drive/MyDrive/SRR17159271_1.fastq -o /content/drive/MyDrive/QC_reports/

# %%
# !wget https://github.com/FelixKrueger/TrimGalore/archive/refs/tags/0.6.10.zip
# !unzip 0.6.10.zip
# !chmod +x TrimGalore-0.6.10/trim_galore
# Out:
# --2024-10-27 10:48:24--  https://github.com/FelixKrueger/TrimGalore/archive/refs/tags/0.6.10.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/FelixKrueger/TrimGalore/zip/refs/tags/0.6.10 [following]
# --2024-10-27 10:48:25--  https://codeload.github.com/FelixKrueger/TrimGalore/zip/refs/tags/0.6.10
# Resolving codeload.github.com (codeload.github.com)... 20.27.177.114
# Connecting to codeload.github.com (codeload.github.com)|20.27.177.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘0.6.10.zip’
#
# 0.6.10.zip              [       <=>          ]  25.59M  17.5MB/s    in 1.5s
#
# 2024-10-27 10:48:27 (17.5 MB/s) - ‘0.6.10.zip’ saved [26835264]
#
# Archive:  0.6.10.zip
# 4edff97d22f3837d42a29e4afbfaeb6e07ffb11b
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mv TrimGalore-0.6.10/trim_galore /usr/local/bin/

# %%
# !pip install cutadapt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.7/287.7 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.9/258.9 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !apt-get install -y isal
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libisal2
# The following NEW packages will be installed:
#   isal libisal2
# 0 upgraded, 2 newly installed, 0 to remove and 50 not upgraded.
# Need to get 121 kB of archives.
# After this operation, 403 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libisal2 amd64 2.30.0-4 [110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 isal amd64 2.30.0-4 [10.7 kB]
# Fetched 121 kB in 1s (89.5 kB/s)
# Selecting previously unselected package libisal2.
# (Reading database ... 124456 files and directories currently installed.)
# Preparing to unpack .../libisal2_2.30.0-4_amd64.deb ...
# Unpacking libisal2 (2.30.0-4) ...
# Selecting previously unselected package isal.
# Preparing to unpack .../isal_2.30.0-4_amd64.deb ...
# Unpacking isal (2.30.0-4) ...
# ...

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17158981_1.fastq /content/drive/MyDrive/SRR17158981_2.fastq -o /content/drive/MyDrive/trimmed_output/
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 4.9
# single-core operation.
# igzip command line interface 2.30.0
# igzip detected. Using igzip for decompressing
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/drive/MyDrive/trimmed_output/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /content/drive/MyDrive/SRR17158981_1.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	8248	AGATCGGAAGAGC	1000000	0.82
# Nextera	1	CTGTCTCTTATA	1000000	0.00
# smallRNA	1	TGGAATTCTCGG	1000000	0.00
# ...

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17158981_1_val_1.fq\
       -2 /content/drive/MyDrive/trimmed_output/SRR17158981_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17158981_aligned.sam
# Out:
# 13773655 reads; of these:
#   13773655 (100.00%) were paired; of these:
#     320822 (2.33%) aligned concordantly 0 times
#     10935239 (79.39%) aligned concordantly exactly 1 time
#     2517594 (18.28%) aligned concordantly >1 times
#     ----
#     320822 pairs aligned concordantly 0 times; of these:
#       37426 (11.67%) aligned discordantly 1 time
#     ----
#     283396 pairs aligned 0 times concordantly or discordantly; of these:
#       566792 mates make up the pairs; of these:
#         304699 (53.76%) aligned 0 times
#         196159 (34.61%) aligned exactly 1 time
#         65934 (11.63%) aligned >1 times
# 98.89% overall alignment rate

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17158981_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17158981_sorted.bam
# Out:
# [bam_sort_core] merging from 15 files and 1 in-memory blocks...

# %%
# !samtools index /content/drive/MyDrive/SRR17158981_sorted.bam

# %%
# !samtools index /content/drive/MyDrive/SRR17159271_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17158981_sorted.bam
# Out:
# 40732515 + 0 in total (QC-passed reads + QC-failed reads)
# 27547310 + 0 primary
# 13185205 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 40427816 + 0 mapped (99.25% : N/A)
# 27242611 + 0 primary mapped (98.89% : N/A)
# 27547310 + 0 paired in sequencing
# 13773655 + 0 read1
# 13773655 + 0 read2
# 26905666 + 0 properly paired (97.67% : N/A)
# 27109944 + 0 with itself and mate mapped
# 132667 + 0 singletons (0.48% : N/A)
# 192472 + 0 with mate mapped to a different chr
# 148778 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17158981_counts.txt -T 4 -p /content/drive/MyDrive/SRR17158981_sorted.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                                                                            ||
# ||                           SRR17158981_sorted.bam                           ||
# ||                                                                            ||
# ...

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17159236_1.fastq /content/drive/MyDrive/SRR17159236_2.fastq -o /content/drive/MyDrive/trimmed_output/
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 4.9
# single-core operation.
# igzip command line interface 2.30.0
# igzip detected. Using igzip for decompressing
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/drive/MyDrive/trimmed_output/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /content/drive/MyDrive/SRR17159236_1.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	28983	AGATCGGAAGAGC	1000000	2.90
# smallRNA	1	TGGAATTCTCGG	1000000	0.00
# Nextera	0	CTGTCTCTTATA	1000000	0.00
# ...

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17159271_1.fastq /content/drive/MyDrive/SRR17159271_2.fastq -o /content/drive/MyDrive/trimmed_output/

# %%
# !apt-get update
# !apt-get install -y hisat2
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,071 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Ign:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17159236_1_val_1.fq\
       -2 /content/drive/MyDrive/trimmed_output/SRR17159236_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17159236_aligned.sam
# Out:
# /bin/bash: line 1: hisat2: command not found

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17158946_1_val_1.fq\
       -2 /content/drive/MyDrive/trimmed_output/SRR17158946_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17158946_aligned.sam
# Out:
# 26287704 reads; of these:
#   26287704 (100.00%) were paired; of these:
#     839435 (3.19%) aligned concordantly 0 times
#     20748935 (78.93%) aligned concordantly exactly 1 time
#     4699334 (17.88%) aligned concordantly >1 times
#     ----
#     839435 pairs aligned concordantly 0 times; of these:
#       61759 (7.36%) aligned discordantly 1 time
#     ----
#     777676 pairs aligned 0 times concordantly or discordantly; of these:
#       1555352 mates make up the pairs; of these:
#         905206 (58.20%) aligned 0 times
#         492915 (31.69%) aligned exactly 1 time
#         157231 (10.11%) aligned >1 times
# 98.28% overall alignment rate

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17158946_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17158946_sorted.bam
# Out:
# [bam_sort_core] merging from 30 files and 1 in-memory blocks...

# %%
# !samtools index /content/drive/MyDrive/SRR17158946_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17158946_sorted.bam
# Out:
# 79217508 + 0 in total (QC-passed reads + QC-failed reads)
# 52575408 + 0 primary
# 26642100 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 78312302 + 0 mapped (98.86% : N/A)
# 51670202 + 0 primary mapped (98.28% : N/A)
# 52575408 + 0 paired in sequencing
# 26287704 + 0 read1
# 26287704 + 0 read2
# 50896538 + 0 properly paired (96.81% : N/A)
# 51315670 + 0 with itself and mate mapped
# 354532 + 0 singletons (0.67% : N/A)
# 391752 + 0 with mate mapped to a different chr
# 293962 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17158946_counts.txt -T 4 -p /content/drive/MyDrive/SRR17158946_sorted.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                                                                            ||
# ||                           SRR17158946_sorted.bam                           ||
# ||                                                                            ||
# ...

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17158978_1_val_1.fq\
       -2 /content/drive/MyDrive/trimmed_output/SRR17158978_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17158978_aligned.sam

# %%
# !apt-get install -y samtools
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# samtools is already the newest version (1.13-4).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17159236_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17159236_sorted.bam
# Out:
# [bam_sort_core] merging from 29 files and 1 in-memory blocks...

# %%
# !samtools index /content/drive/MyDrive/SRR17159236_sorted.bam

# %%
# !samtools index /content/drive/MyDrive/SRR17159271_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17159271_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17159236_sorted.bam
# Out:
# 77413698 + 0 in total (QC-passed reads + QC-failed reads)
# 64453566 + 0 primary
# 12960132 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 76837208 + 0 mapped (99.26% : N/A)
# 63877076 + 0 primary mapped (99.11% : N/A)
# 64453566 + 0 paired in sequencing
# 32226783 + 0 read1
# 32226783 + 0 read2
# 63229614 + 0 properly paired (98.10% : N/A)
# 63506552 + 0 with itself and mate mapped
# 370524 + 0 singletons (0.57% : N/A)
# 246752 + 0 with mate mapped to a different chr
# 191859 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17159271_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17159271_sorted.bam

# %%
# !samtools index /content/drive/MyDrive/SRR17159271_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17159271_sorted.bam

# %%
# !apt-get install -y subread
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   subread
# 0 upgraded, 1 newly installed, 0 to remove and 50 not upgraded.
# Need to get 565 kB of archives.
# After this operation, 1,928 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 subread amd64 2.0.3+dfsg-1 [565 kB]
# Fetched 565 kB in 2s (353 kB/s)
# Selecting previously unselected package subread.
# (Reading database ... 124421 files and directories currently installed.)
# Preparing to unpack .../subread_2.0.3+dfsg-1_amd64.deb ...
# Unpacking subread (2.0.3+dfsg-1) ...
# Setting up subread (2.0.3+dfsg-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17159236_counts.txt -T 4 -p /content/drive/MyDrive/SRR17159236_sorted.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                                                                            ||
# ||                           SRR17159236_sorted.bam                           ||
# ||                                                                            ||
# ...

# %%
# !fastqc /content/drive/MyDrive/SRR17159276_2.fastq -o /content/drive/MyDrive/QC_reports/
# Out:
# Started analysis of SRR17159276_2.fastq
# Approx 5% complete for SRR17159276_2.fastq
# Approx 10% complete for SRR17159276_2.fastq
# Approx 15% complete for SRR17159276_2.fastq
# Approx 20% complete for SRR17159276_2.fastq
# Approx 25% complete for SRR17159276_2.fastq
# Approx 30% complete for SRR17159276_2.fastq
# Approx 35% complete for SRR17159276_2.fastq
# Approx 40% complete for SRR17159276_2.fastq
# Approx 45% complete for SRR17159276_2.fastq
# Approx 50% complete for SRR17159276_2.fastq
# Approx 55% complete for SRR17159276_2.fastq
# Approx 60% complete for SRR17159276_2.fastq
# Approx 65% complete for SRR17159276_2.fastq
# Approx 70% complete for SRR17159276_2.fastq
# Approx 75% complete for SRR17159276_2.fastq
# Approx 80% complete for SRR17159276_2.fastq
# Approx 85% complete for SRR17159276_2.fastq
# Approx 90% complete for SRR17159276_2.fastq
# Approx 95% complete for SRR17159276_2.fastq
# Analysis complete for SRR17159276_2.fastq

# %%
# !fastqc /content/drive/MyDrive/SRR17158978_2.fastq -o /content/drive/MyDrive/QC_reports/
# Out:
# Started analysis of SRR17158978_2.fastq
# Approx 5% complete for SRR17158978_2.fastq
# Approx 10% complete for SRR17158978_2.fastq
# Approx 15% complete for SRR17158978_2.fastq
# Approx 20% complete for SRR17158978_2.fastq
# Approx 25% complete for SRR17158978_2.fastq
# Approx 30% complete for SRR17158978_2.fastq
# Approx 35% complete for SRR17158978_2.fastq
# Approx 40% complete for SRR17158978_2.fastq
# Approx 45% complete for SRR17158978_2.fastq
# Approx 50% complete for SRR17158978_2.fastq
# Approx 55% complete for SRR17158978_2.fastq
# Approx 60% complete for SRR17158978_2.fastq
# Approx 65% complete for SRR17158978_2.fastq
# Approx 70% complete for SRR17158978_2.fastq
# Approx 75% complete for SRR17158978_2.fastq
# Approx 80% complete for SRR17158978_2.fastq
# Approx 85% complete for SRR17158978_2.fastq
# Approx 90% complete for SRR17158978_2.fastq
# Approx 95% complete for SRR17158978_2.fastq
# Analysis complete for SRR17158978_2.fastq

# %%
# !trim_galore --paired --quality 20 --length 20 /content/drive/MyDrive/SRR17159238_1.fastq /content/drive/MyDrive/SRR17159238_2.fastq -o /content/drive/MyDrive/trimmed_output/
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 4.9
# single-core operation.
# igzip command line interface 2.30.0
# igzip detected. Using igzip for decompressing
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/drive/MyDrive/trimmed_output/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /content/drive/MyDrive/SRR17159238_1.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	32723	AGATCGGAAGAGC	1000000	3.27
# smallRNA	0	TGGAATTCTCGG	1000000	0.00
# Nextera	0	CTGTCTCTTATA	1000000	0.00
# ...

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17159238_1_val_1.fq \
       -2 /content/drive/MyDrive/trimmed_output/SRR17159238_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17159238_aligned.sam
# Out:
# 39522320 reads; of these:
#   39522320 (100.00%) were paired; of these:
#     852828 (2.16%) aligned concordantly 0 times
#     31906198 (80.73%) aligned concordantly exactly 1 time
#     6763294 (17.11%) aligned concordantly >1 times
#     ----
#     852828 pairs aligned concordantly 0 times; of these:
#       65714 (7.71%) aligned discordantly 1 time
#     ----
#     787114 pairs aligned 0 times concordantly or discordantly; of these:
#       1574228 mates make up the pairs; of these:
#         781927 (49.67%) aligned 0 times
#         614838 (39.06%) aligned exactly 1 time
#         177463 (11.27%) aligned >1 times
# 99.01% overall alignment rate

# %%
39522320 reads; of these:
  39522320 (100.00%) were paired; of these:
    852828 (2.16%) aligned concordantly 0 times
    31906198 (80.73%) aligned concordantly exactly 1 time
    6763294 (17.11%) aligned concordantly >1 times
    ----
    852828 pairs aligned concordantly 0 times; of these:
      65714 (7.71%) aligned discordantly 1 time
    ----
    787114 pairs aligned 0 times concordantly or discordantly; of these:
      1574228 mates make up the pairs; of these:
        781927 (49.67%) aligned 0 times
        614838 (39.06%) aligned exactly 1 time
        177463 (11.27%) aligned >1 times
99.01% overall alignment rate

# %%
# !hisat2 -x /content/drive/MyDrive/reference_index/GRCm39_index \
       -1 /content/drive/MyDrive/trimmed_output/SRR17158978_1_val_1.fq \
       -2 /content/drive/MyDrive/trimmed_output/SRR17158978_2_val_2.fq \
       -S /content/drive/MyDrive/SRR17158978_aligned.sam
# Out:
# 18789132 reads; of these:
#   18789132 (100.00%) were paired; of these:
#     452122 (2.41%) aligned concordantly 0 times
#     14660851 (78.03%) aligned concordantly exactly 1 time
#     3676159 (19.57%) aligned concordantly >1 times
#     ----
#     452122 pairs aligned concordantly 0 times; of these:
#       35346 (7.82%) aligned discordantly 1 time
#     ----
#     416776 pairs aligned 0 times concordantly or discordantly; of these:
#       833552 mates make up the pairs; of these:
#         501903 (60.21%) aligned 0 times
#         251503 (30.17%) aligned exactly 1 time
#         80146 (9.61%) aligned >1 times
# 98.66% overall alignment rate

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17159238_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17159238_sorted.bam
# Out:
# [bam_sort_core] merging from 36 files and 1 in-memory blocks...

# %%
# !samtools view -bS /content/drive/MyDrive/SRR17158978_aligned.sam | samtools sort -o /content/drive/MyDrive/SRR17158978_sorted.bam
# Out:
# [bam_sort_core] merging from 22 files and 1 in-memory blocks...

# %%
# !samtools index /content/drive/MyDrive/SRR17158978_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17158978_sorted.bam
# Out:
# 58309766 + 0 in total (QC-passed reads + QC-failed reads)
# 37578264 + 0 primary
# 20731502 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 57807863 + 0 mapped (99.14% : N/A)
# 37076361 + 0 primary mapped (98.66% : N/A)
# 37578264 + 0 paired in sequencing
# 18789132 + 0 read1
# 18789132 + 0 read2
# 36674020 + 0 properly paired (97.59% : N/A)
# 36893632 + 0 with itself and mate mapped
# 182729 + 0 singletons (0.49% : N/A)
# 201706 + 0 with mate mapped to a different chr
# 153554 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !samtools index /content/drive/MyDrive/SRR17159238_sorted.bam

# %%
# !samtools flagstat /content/drive/MyDrive/SRR17159238_sorted.bam
# Out:
# 95387991 + 0 in total (QC-passed reads + QC-failed reads)
# 79044640 + 0 primary
# 16343351 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 94606064 + 0 mapped (99.18% : N/A)
# 78262713 + 0 primary mapped (99.01% : N/A)
# 79044640 + 0 paired in sequencing
# 39522320 + 0 read1
# 39522320 + 0 read2
# 77338984 + 0 properly paired (97.84% : N/A)
# 77687442 + 0 with itself and mate mapped
# 575271 + 0 singletons (0.73% : N/A)
# 304454 + 0 with mate mapped to a different chr
# 222808 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17158978_counts.txt -T 4 -p /content/drive/MyDrive/SRR17158978_sorted.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                                                                            ||
# ||                           SRR17158978_sorted.bam                           ||
# ||                                                                            ||
# ...

# %%
# !featureCounts -a /content/drive/MyDrive/gencode.vM35.basic.annotation.gtf -o /content/drive/MyDrive/SRR17159238_counts.txt -T 4 -p /content/drive/MyDrive/SRR17159238_sorted.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                                                                            ||
# ||                           SRR17159238_sorted.bam                           ||
# ||                                                                            ||
# ...
